# %%
import ltspice
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})

# %%
l = ltspice.Ltspice('Mikrophonverst.raw')
l.parse()

# %%
f = l.getTime()
noiseAmp = l.getData('V(onoise)')

# %%
plt.figure(figsize = (10,5))
plt.semilogx(f, noiseAmp)
plt.ylabel(r'Rauschspannungsdichte in $\frac{\text{V}}{\sqrt{Hz}}$')
plt.xlabel('Frequenz in Hz')
plt.grid(True, which='both')
plt.xlim([10e-4, 10e7])
plt.xticks([1e-3,1e-2,1e-1,1e-0,1e1,1e2,1e3,1e4,1e5,1e6,1e7,1e8])
plt.title(r'Rauschverhalten am Ausgang')
plt.savefig('Rauschleistung.pdf', bbox_inches = 'tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     303         try:
# --> 304             report = subprocess.check_output(command,
#     305                                              cwd=self.texcache,
#
# ~\anaconda3\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     410
# --> 411     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     412                **kwargs).stdout
#
# ~\anaconda3\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     511         if check and retcode:
# --> 512             raise CalledProcessError(retcode, process.args,
#     513                                      output=stdout, stderr=stderr)
#
# ...

# %%
l.getTime()
# Out:
# array([1.00000000e-05, 1.02329299e-05, 1.04712855e-05, ...,
#        9.54992586e+07, 9.77237221e+07, 1.00000000e+08])

# %%
f
