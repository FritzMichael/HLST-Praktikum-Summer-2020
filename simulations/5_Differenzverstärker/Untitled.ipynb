# %%
import ltspice
import matplotlib.pyplot as plt
import numpy as np

# %%
l = ltspice.Ltspice('MillerOP_neu.raw')
l.parse()

# %%
t = l.getTime()
V_out = l.getData('V(n008)')

# %%
plt.figure(figsize = (10,5))
plt.plot(t, V_out)
plt.xlim([0.1,0.15])
plt.ylabel('Spannung in V')
plt.xlabel('Zeit in Sekunden')
plt.grid(True)
plt.title(r'Verlauf der Ausgangsspannung bei Brummspannung auf')
plt.savefig('BaseEmitterVoltage.pdf', bbox_inches = 'tight')
plt.show()
